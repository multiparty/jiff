# %%
# !python3 -m pip install geoql
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages/geoql')
sys.path.append('/usr/local/lib/python3.6/site-packages/geojson')

# %%
import geoql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-2bae36900b6f> in <module>()
# ----> 1 import geoql
#
# /usr/local/lib/python3.6/site-packages/geoql/geoql.py in <module>()
#      13 import types
#      14 import json
# ---> 15 import geojson
#      16 import geopy.distance
#      17 import rtree
#
# ModuleNotFoundError: No module named 'geojson'
